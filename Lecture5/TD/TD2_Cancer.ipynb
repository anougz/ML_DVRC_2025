# %% [markdown]
# ### Jupyter Notebook — TD : Classification sur Breast Cancer Dataset

# %% [markdown]
# **Objectifs :**
# - Inderstand supervised classification
# - Test 4 models : Logistic Regression, Decision Tree, Random Forest, KNN
# - Visualize matrix of confusion & metrics
# - Answer final questions

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# -------------------------------
# 1. Chargement du dataset
# -------------------------------
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

print("Shape X :", X.shape)
print("Labels :", data.target_names)
# Out:
# Shape X : (569, 30)
# Labels : ['malignant' 'benign']

# %%
# 2. Train / Test split
# -------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42, stratify=y
)

# %%
# -------------------------------
# 3. Standardisation
# -------------------------------
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# -------------------------------
# 4. Modèles à tester
# -------------------------------
models = {
    "Logistic Regression": LogisticRegression(max_iter=500),
    "Decision Tree": DecisionTreeClassifier(max_depth=5),
    "Random Forest": RandomForestClassifier(n_estimators=200),
    "KNN": KNeighborsClassifier(n_neighbors=7)
}
results = {}

# %%
# 5. Entraînement & Évaluation
# -------------------------------
for name, model in models.items():
    model.fit(X_train_scaled, y_train)

    preds = model.predict(X_test_scaled)

    acc = accuracy_score(y_test, preds)
    
    cm = confusion_matrix(y_test, preds)
    report = classification_report(y_test, preds, target_names=data.target_names)

    results[name] = (acc, cm, report)

    print("=" * 60)
    print(name)
    print("Accuracy :", acc)
    print("Matrice de confusion :\n", cm)
    print("Classification Report :\n", report)

    # heatmap
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Matrice de confusion - {name}")
    plt.xlabel("Prédit")
    plt.ylabel("Réel")
    plt.show()
# Out:
# ...
# Logistic Regression
# Accuracy : 0.9883040935672515
# Matrice de confusion :
#  [[ 63   1]
#  [  1 106]]
# Classification Report :
#                precision    recall  f1-score   support
#
#    malignant       0.98      0.98      0.98        64
#       benign       0.99      0.99      0.99       107
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171
# ...
# Decision Tree
# Accuracy : 0.9239766081871345
# Matrice de confusion :
#  [[ 57   7]
#  [  6 101]]
# Classification Report :
#                precision    recall  f1-score   support
#
#    malignant       0.90      0.89      0.90        64
#       benign       0.94      0.94      0.94       107
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.92      0.92       171
# weighted avg       0.92      0.92      0.92       171
# ...
# Random Forest
# Accuracy : 0.9298245614035088
# ...

# %% [markdown]
# ### QUESTIONS & UPGRADE
#
#
# 1. Which model achieves the best accuracy? Why, in your opinion?
#
# 2. Compare the Recall for the “malignant” class.
# → Which model detects cancers the best?
#
# 3. Compare the Precision for the same class.
# → Which model minimizes false positives the most?
#
# 4. Decision Tree
# → What happens if we remove the constraint max_depth = 5?
#
# 5. K-Nearest Neighbors (KNN)
# → How does performance change when testing k = 1, 3, 5, 15?
#
# 6. In a real medical scenario, which metric is the most important?
# - Precision?
# - Recall?
# - F1-score?
# Justify your choice.
#
# 7. Propose an improved ML pipeline
# Consider:
# * Feature selection
# * Normalization / standardization
# * Cross-validation strategy
